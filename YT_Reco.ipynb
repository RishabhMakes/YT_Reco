# %%
print("Starting stuff")
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from secrets import *
import time
import random
import numpy
import pandas
# print(secrets.passkey)
# Out:
# Starting stuff

# %% [markdown]
# ### Initiate Chrome

# %%
driver = webdriver.Firefox()
# opts.binary_location = "D:\Program Files (x86)\Google\Chrome\Application\chrome.exe"
# driver = webdriver.Chrome(chrome_options = opts)

# %% [markdown]
# ### Go to YT Login

# %%
driver.get('https://accounts.google.com/signin/v2/identifier?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3Dhttps%253A%252F%252Fwww.youtube.com%252F&hl=en&ec=65620&flowName=GlifWebSignIn&flowEntry=ServiceLogin')
username = driver.find_element_by_id('identifierId')
username.send_keys('USERNAME')
time.sleep(2)
username.send_keys(Keys.RETURN)
time.sleep(2)

# %%
password = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[2]/div/div[2]/div/div/div[2]/div/div[1]/div/form/span/section/div/div/div[1]/div[1]/div/div/div/div/div[1]/div/div[1]/input')
password.send_keys('PASS')
time.sleep(2)
password.send_keys(Keys.RETURN)

# %%
times = driver.find_element_by_class_name('style-scope ytd-thumbnail-overlay-time-status-renderer')
type(times)
# Out:
# selenium.webdriver.firefox.webelement.FirefoxWebElement

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
videos = soup.find_all(class_="ytd-rich-grid-video-renderer", attrs={"id": "video-title-link"})
# durations = soup("a")
print(len(videos))
for video in videos:
    print(video.attrs['title'], video.attrs['href'])
# print(durations[0].string)
# Out:
# 67
# “Designing Intrinsic Layouts” by Jen Simmons—An Event Apart video /watch?v=AMPKmh98XLY
# Ramachandra Guha on Savarkar’s hatred for Gandhi, HT spiking his column and more /watch?v=J8TwQ7dQMIc
# THE MOST HORRIBLE BROTHERS AND SISTERS /watch?v=Apt_giRCyAU
# Arboretum - Shut Up & Sit Down Review (with Spicy Trees) /watch?v=mmiXSOG1BtQ
# The Bitter Economics of MLM's /watch?v=inPcztqj9RE
# Jeff Bezos: The electricity metaphor /watch?v=vMKNUylmanQ
# भारत में Coronavirus का कहर जारी, अब तक 29,435 लोग हो चुके हैं संक्रमित /watch?v=t6K30NxtV8I
# Android on Nintendo Switch is AMAZING. /watch?v=REx_qSTulJM
# Stop making your UI's boring - UI/UX Workshop /watch?v=erA1Q0jmO4A
# Ken Jeong Breaks Down His Most Iconic Characters | GQ /watch?v=ZSepCNhEWDA
# Fuzzy Logic - Computerphile /watch?v=r804UF8Ia4c
# The Best Milk Drinks At Home Without an Espresso Machine /watch?v=ZgIVfU0xBjA
# 20 Signs You're Emotionally Mature /watch?v=k-J9BVBjK3o
# Station Delhi - Young Turks - Demographic Dividend - Part 2 /watch?v=B8hnYVdsCfU
# Adam Savage's One Day Builds: Overengineered Bottle Opener! /watch?v=MxLOoriXkMc
# Eternal Sunshine: Is It Deep or Dumb? – Wisecrack Edition /watch?v=gGmL8P0IobI
# How to Make The Best Hot Chocolate Of All Time (4 ways) /watch?v=pn-W0DVQw8Y
# Oil Prices Collapse (-$38 a Barrel): What The Hell Just Happened? - TLDR News /watch?v=sdQk9LOdWt4
# Learn JAVASCRIPT in just 5 MINUTES (2020) /watch?v=c-I5S_zTwAc
# Can You Guess Who The Mother Is? (IMPOSSIBLE CHALLENGE) /watch?v=B5kgn861RYs
# SGN Potluck: Some Good News with John Krasinski Ep. 5 /watch?v=o1zIgTwENPg
# Solving the Japanese COFFEE CUP Puzzle!! With Peter McKinnon /watch?v=8vbXQPX57xk
# The Rise of Open Source Communities in China /watch?v=RFjIBM0TR7U
# “Revolutionize Your Page” by Jen Simmons – An Event Apart Orlando 2016 /watch?v=aYgMExb-mlo
# Kabhi Khushi Kabhi Gham: TheRevisits /watch?v=wL_yL1FiBHM
# Bow Hunter Breaks Down Bow and Arrow Scenes from Movies & TV | GQ /watch?v=pdipblQmgnw
# Geopolitics of Jordan /watch?v=R6F-HkTUXPU
# 20,000 Crore Central Vista Redevelopment - Mungerilal Ke Haseen Sapne? | Analysis on The Deshbhakt /watch?v=TChypRlZ0oE
# DIY 87-Key Macro Keyboard - Because he has too many keyboard shortcuts! /watch?v=Arn8ExQ2Gjg
# John McAfee: The Craziest Man In Tech (Part 1/4) /watch?v=IH_8eRTAXHo
# 11 different egg dishes I've tried for the first time /watch?v=OjPD2J6MdCM
# Pricing Design Work & Creativity /watch?v=RKXZ7t_RiOE
# YouTube's Copyright System Isn't Broken. The World's Is. /watch?v=1Jwo5qc78QU
# The BEST Webcam is One That You CAN'T BUY (and it's huuuuuge) /watch?v=t0pAcN0e9SU
# Bohri Thali VS. Gujarati Thali | Menu Please ft. Kaneez Surka | Netflix India /watch?v=Wq9jbgj89ow
# How Marvelman Changed Superheroes /watch?v=Z2yZwh_gCIU
# Millionaire's Shortbread Just Like I Grew Up With In Ireland /watch?v=cm6U44w4CAE
# The Controversial Guru Who Wants to 'Upgrade Civilization' /watch?v=RWUZnYCe0QA
# Innovative & Practical Graphic Design with CSS Grid /watch?v=-hmOZU7Zk10
# Binging with Babish: Pasta Puttanesca from Lemony Snicket's A Series of Unfortunate Events /watch?v=uwV9cq9DRTY
# The UX Infinity Gems   6 Ways to Create Great UX /watch?v=aZZCZpc0AcY
# Intel did something Right? - Ghost Canyon NUC 9 Extreme Review /watch?v=uuNaaar6C5g
# The Office: How Nonsense Conquered the Workplace – Wisecrack Edition /watch?v=_Lngf3J8vN4
# Point and Click Puzzle Design | How to Design Puzzles /watch?v=EDt6XXsRXag
# Abstract: The Art of Design | Paula Scher: Graphic Design | FULL EPISODE | Netflix /watch?v=LCfBYE97rFk
# Angular vs React vs Vue [2020 Update] /watch?v=lYWYWyX04JI
# The Easiest Way To Make Any Homemade Fruit Jam (feat. Krewella) /watch?v=KUGjgUA-BWU
# 90's Kids Then Vs. Now /watch?v=oZxkXQcRGjc
# Animated Responsive Navbar with CSS - Plus Other Useful Tricks /watch?v=biOMz4puGt8
# Mix - Heroes (2017 Remaster) /watch?v=YLp2cW7ICCU&list=RDYLp2cW7ICCU&start_radio=1
# We need to talk about male suicide | Steph Slack | TEDxFolkestone /watch?v=Q3WDw-DBKLA
# Newslaundry Hindi Team: LIVE Chat! /watch?v=UVoUdkYt8Bk
# 11 Chef Skills I Learned Making Fresh Lasagna... /watch?v=94d7ZXySplo
# Starting The Branding Process – Building A Brand, Episode 1 /watch?v=mxgOY2Ms-YI
# Why Do Screens Need Ugly BORDERS? /watch?v=zY8GG_5H6Ss
# Reversing Ageing: New Studies Show it Can be Done /watch?v=XlFl0jDg0Jg
# Building the Xbox Series X Rip-off PC /watch?v=Sv3Pqb2F_xc
# How to Convert any Python File to .EXE /watch?v=UZX5kH72Yx4
# The 1929 Stock Market Crash - Black Thursday - Extra History /watch?v=D2iuUzkKu9k
# Binging with Babish Tries to Keep Up with a Professional Chef | Back-to-Back Chef | Bon Appétit /watch?v=RpSonCYCn1U
# Zoom company story: How Eric Yuan defeated Skype /watch?v=p9YUjzmiiSk
# Ubuntu 20.04 LTS is the best release yet! (Full Review) /watch?v=T09xdwPSqIQ
# MAKE ME SUFFER CHALLENGE /watch?v=Dj8YyFAxzX8
# Explained | World's Water Crisis | FULL EPISODE | Netflix /watch?v=C65iqOSCZOY
# How to Choose a Password - Computerphile /watch?v=3NjQ9b3pgIg
# Trendy Vs. Traditional: Pie • Tasty /watch?v=yz5UyX-gqvU
# Gatsby JS - The Great Gatsby Bootcamp [Full Tutorial] /watch?v=8t0vNu2fCCM

# %%
def parse_time(raw):
    pos=raw.index('ago')
    print(pos, raw[pos])
    return(raw[(pos+1):-2])
    
def parse_channel(raw):
    pos = raw.index('by')
    print(pos, raw[pos+1:])

for video in videos:
    raw = video.attrs['aria-label'].split()
    
    print("Title: ", video.attrs['title'])
    print("Duration: ", parse_time(raw))
    print("Views: ",raw[-2], "\n")
# Out:
# 15 ago
# Title:  “Designing Intrinsic Layouts” by Jen Simmons—An Event Apart video
# 15 ago
# Duration:  ['59', 'minutes']
# Views:  1,056
#
# 17 ago
# Title:  Ramachandra Guha on Savarkar’s hatred for Gandhi, HT spiking his column and more
# 17 ago
# Duration:  ['8', 'minutes,', '51', 'seconds']
# Views:  2,430
#
# 11 ago
# Title:  THE MOST HORRIBLE BROTHERS AND SISTERS
# 11 ago
# Duration:  ['10', 'minutes,', '7', 'seconds']
# Views:  1,921,140
#
# 19 ago
# Title:  Arboretum - Shut Up & Sit Down Review (with Spicy Trees)
# 19 ago
# Duration:  ['19', 'minutes']
# Views:  119,456
#
# 10 ago
# Title:  The Bitter Economics of MLM's
# 10 ago
# Duration:  ['12', 'minutes,', '28', 'seconds']
# Views:  287,696
#
# 9 ago
# Title:  Jeff Bezos: The electricity metaphor
# 9 ago
# Duration:  ['19', 'minutes']
# Views:  855,767
#
# 19 ago
# Title:  भारत में Coronavirus का कहर जारी, अब तक 29,435 लोग हो चुके हैं संक्रमित
# 19 ago
# Duration:  ['3', 'minutes,', '30', 'seconds']
# Views:  2,869,558
#
# 12 ago
# Title:  Android on Nintendo Switch is AMAZING.
# 12 ago
# Duration:  ['18', 'minutes']
# Views:  2,326,345
#
# 12 ago
# Title:  Stop making your UI's boring - UI/UX Workshop
# 12 ago
# Duration:  ['6', 'minutes,', '30', 'seconds']
# Views:  45,371
#
# 14 ago
# Title:  Ken Jeong Breaks Down His Most Iconic Characters | GQ
# 14 ago
# Duration:  ['21', 'minutes']
# Views:  2,424,201
#
# 8 ago
# Title:  Fuzzy Logic - Computerphile
# 8 ago
# Duration:  ['9', 'minutes,', '2', 'seconds']
# Views:  313,706
#
# 15 ago
# Title:  The Best Milk Drinks At Home Without an Espresso Machine
# 15 ago
# Duration:  ['17', 'minutes']
# Views:  336,982
#
# 12 ago
# Title:  20 Signs You're Emotionally Mature
# 12 ago
# Duration:  ['7', 'minutes,', '57', 'seconds']
# Views:  1,868,389
#
# 15 ago
# Title:  Station Delhi - Young Turks - Demographic Dividend - Part 2
# 15 ago
# Duration:  ['29', 'minutes']
# Views:  1,100,502
#
# 14 ago
# Title:  Adam Savage's One Day Builds: Overengineered Bottle Opener!
# 14 ago
# Duration:  ['46', 'minutes']
# Views:  2,108,610
#
# 14 ago
# Title:  Eternal Sunshine: Is It Deep or Dumb? – Wisecrack Edition
# 14 ago
# Duration:  ['17', 'minutes']
# Views:  95,264
#
# 17 ago
# Title:  How to Make The Best Hot Chocolate Of All Time (4 ways)
# 17 ago
# Duration:  ['6', 'minutes,', '14', 'seconds']
# Views:  3,537,421
#
# 20 ago
# Title:  Oil Prices Collapse (-$38 a Barrel): What The Hell Just Happened? - TLDR News
# 20 ago
# Duration:  ['10', 'minutes,', '6', 'seconds']
# Views:  146,554
#
# 12 ago
# Title:  Learn JAVASCRIPT in just 5 MINUTES (2020)
# 12 ago
# Duration:  ['5', 'minutes,', '15', 'seconds']
# Views:  394,328
#
# 14 ago
# Title:  Can You Guess Who The Mother Is? (IMPOSSIBLE CHALLENGE)
# 14 ago
# Duration:  ['10', 'minutes,', '41', 'seconds']
# Views:  857,448
#
# 14 ago
# Title:  SGN Potluck: Some Good News with John Krasinski Ep. 5
# 14 ago
# Duration:  ['15', 'minutes']
# Views:  2,338,891
#
# 14 ago
# Title:  Solving the Japanese COFFEE CUP Puzzle!! With Peter McKinnon
# 14 ago
# Duration:  ['10', 'minutes,', '4', 'seconds']
# Views:  2,107,761
#
# 12 ago
# Title:  The Rise of Open Source Communities in China
# 12 ago
# Duration:  ['11', 'minutes,', '21', 'seconds']
# Views:  7,959
#
# 18 ago
# Title:  “Revolutionize Your Page” by Jen Simmons – An Event Apart Orlando 2016
# 18 ago
# Duration:  ['1', 'hour']
# Views:  4,409
#
# 10 ago
# Title:  Kabhi Khushi Kabhi Gham: TheRevisits
# 10 ago
# Duration:  ['4', 'minutes,', '12', 'seconds']
# Views:  1,228,855
#
# 18 ago
# Title:  Bow Hunter Breaks Down Bow and Arrow Scenes from Movies & TV | GQ
# 18 ago
# Duration:  ['19', 'minutes']
# Views:  6,888,097
#
# 7 ago
# Title:  Geopolitics of Jordan
# 7 ago
# Duration:  ['15', 'minutes']
# Views:  108,097
#
# 20 ago
# Title:  20,000 Crore Central Vista Redevelopment - Mungerilal Ke Haseen Sapne? | Analysis on The Deshbhakt
# 20 ago
# Duration:  ['13', 'minutes,', '4', 'seconds']
# Views:  324,531
#
# 18 ago
# Title:  DIY 87-Key Macro Keyboard - Because he has too many keyboard shortcuts!
# 18 ago
# Duration:  ['10', 'minutes,', '41', 'seconds']
# Views:  1,692,834
#
# 15 ago
# Title:  John McAfee: The Craziest Man In Tech (Part 1/4)
# 15 ago
# Duration:  ['9', 'minutes,', '13', 'seconds']
# Views:  1,177,453
#
# 15 ago
# Title:  11 different egg dishes I've tried for the first time
# 15 ago
# Duration:  ['13', 'minutes,', '24', 'seconds']
# Views:  2,208,077
#
# 10 ago
# Title:  Pricing Design Work & Creativity
# 10 ago
# Duration:  ['36', 'minutes']
# Views:  2,663,715
#
# 13 ago
# Title:  YouTube's Copyright System Isn't Broken. The World's Is.
# 13 ago
# Duration:  ['42', 'minutes']
# Views:  1,987,639
#
# 17 ago
# Title:  The BEST Webcam is One That You CAN'T BUY (and it's huuuuuge)
# 17 ago
# Duration:  ['10', 'minutes,', '7', 'seconds']
# Views:  92,543
#
# 19 ago
# Title:  Bohri Thali VS. Gujarati Thali | Menu Please ft. Kaneez Surka | Netflix India
# 19 ago
# Duration:  ['12', 'minutes,', '34', 'seconds']
# Views:  345,508
#
# 8 ago
# Title:  How Marvelman Changed Superheroes
# 8 ago
# Duration:  ['7', 'minutes,', '55', 'seconds']
# Views:  165,138
#
# 16 ago
# Title:  Millionaire's Shortbread Just Like I Grew Up With In Ireland
# 16 ago
# Duration:  ['8', 'minutes,', '56', 'seconds']
# Views:  168,785
#
# 12 ago
# Title:  The Controversial Guru Who Wants to 'Upgrade Civilization'
# 12 ago
# Duration:  ['25', 'minutes']
# Views:  1,284,218
#
# 13 ago
# Title:  Innovative & Practical Graphic Design with CSS Grid
# 13 ago
# Duration:  ['14', 'minutes,', '20', 'seconds']
# Views:  22,650
#
# 19 ago
# Title:  Binging with Babish: Pasta Puttanesca from Lemony Snicket's A Series of Unfortunate Events
# 19 ago
# Duration:  ['7', 'minutes,', '14', 'seconds']
# Views:  4,196,582
#
# 14 ago
# Title:  The UX Infinity Gems   6 Ways to Create Great UX
# 14 ago
# Duration:  ['33', 'minutes']
# Views:  248,627
#
# 17 ago
# Title:  Intel did something Right? - Ghost Canyon NUC 9 Extreme Review
# 17 ago
# Duration:  ['12', 'minutes,', '2', 'seconds']
# Views:  849,218
#
# 14 ago
# Title:  The Office: How Nonsense Conquered the Workplace – Wisecrack Edition
# 14 ago
# Duration:  ['19', 'minutes']
# Views:  1,196,801
#
# 16 ago
# Title:  Point and Click Puzzle Design | How to Design Puzzles
# 16 ago
# Duration:  ['9', 'minutes,', '40', 'seconds']
# Views:  482,823
#
# 19 ago
# Title:  Abstract: The Art of Design | Paula Scher: Graphic Design | FULL EPISODE | Netflix
# 19 ago
# Duration:  ['40', 'minutes']
# Views:  74,950
#
# 11 ago
# Title:  Angular vs React vs Vue [2020 Update]
# 11 ago
# Duration:  ['28', 'minutes']
# Views:  82,661
#
# 16 ago
# Title:  The Easiest Way To Make Any Homemade Fruit Jam (feat. Krewella)
# 16 ago
# Duration:  ['6', 'minutes,', '53', 'seconds']
# Views:  334,262
#
# 10 ago
# Title:  90's Kids Then Vs. Now
# 10 ago
# Duration:  ['11', 'minutes,', '29', 'seconds']
# Views:  833,023
#
# 14 ago
# Title:  Animated Responsive Navbar with CSS - Plus Other Useful Tricks
# 14 ago
# Duration:  ['11', 'minutes,', '40', 'seconds']
# Views:  251,583
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-3a391aa2816b> in <module>
#       6
#       7 for video in videos:
# ----> 8     raw = video.attrs['aria-label'].split()
#       9     duration=parse_time(raw)
#      10     print("Title: ", video.attrs['title'])
#
# KeyError: 'aria-label'
